# %%
import random
data=[]
total_users=0
def createAccount():              
    user={}
    user["name"]=input("Enter user name=")
    global total_users
    total_users+=1
    user["id"]="ADDA"+str(total_users)
    user["password"]=input("Enter password=")
    user["amount"]=int(input("Enter opening account balance="))
    user["games_played"]=0
    data.append(user)
    print("Account Created Successfully ....!!!")
    print("-"*30,"Account Details","-"*30)
    print("\tUser Id:",user["id"],"\t\tUser Name:",user["name"],"\t\tBalance Amount:",user["amount"])
    print("-"*60)

def addMoney(data):
    id=input("Enter User Id : ")
    password=input("Enter User Password : ")
    isUserFound=False
    for x in range(len(data)):
        if data[x]["id"]==id and data[x]["password"]==password:
            isUserFound=True
            print("-"*30,"Your Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
            
            amount=int(input("Enter Amount To Add : "))
            data[x]["amount"]=data[x]["amount"]+amount
            
            print("Amount Added Successfully ....!!!")
            print("-"*30,"Updated Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
    if isUserFound==False:
        print("Invalid Id or Password ......!!!!\n")

def withdrawMoney(data):
    id=input("Enter User Id : ")
    password=input("Enter User Password : ")
    isUserFound=False
    for x in range(len(data)):
        if data[x]["id"]==id and data[x]["password"]==password:
            isUserFound=True
            print("-"*30,"Your Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
            
            amount=int(input("Enter Amount To Deduct/Withdraw : "))
            data[x]["amount"]=data[x]["amount"]-amount
            
            print("Amount Added Successfully ....!!!")
            print("-"*30,"Updated Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
    if isUserFound==False:
        print("Invalid Id or Password ......!!!!\n")

def BlackAndWhite(data):
    id=input("Enter User Id : ")
    password=input("Enter User Password : ")
    isUserFound=False
    userIndex=0
    while isUserFound==False:
        for x in range(len(data)):
            if data[x]["id"]==id and data[x]["password"]==password:
                isUserFound=True
                userIndex=x
                print("-"*30,"Your Account Details","-"*30)
                print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
                print("-"*60)
        if isUserFound==False:
            print("Invalid Id or Password ......!!!!\n")
            print("Please Enter Correct Details Again....!!!\n")
            id=input("Enter User Id : ")
            password=input("Enter User Password : ")
    if isUserFound==True and data[userIndex]["amount"]>0:
        print("Welcome To Black & White Game")
        print("Rules :\n1. You have To select your color(Black / White)\n2. Enter Bet Amount\n3. If your Selected color comes then You WON the game other You Loose")
        print("4. Winning Amount = Bet Amount * 1.5")
        gameRound=0
        playChoice="yes"
        while playChoice.lower()=="yes" and data[userIndex]["amount"]>0:
            gameRound+=1
            print("\t\t\tBlack & White")
            print("Round : ",gameRound,"\tWallet Balance : ",data[userIndex]["amount"],"\tTotal Games Played :",data[userIndex]["games_played"])
            data[userIndex]["games_played"]+=1
            print("\n\n1. Black\n2. White\n")
            color=int(input("Select Your Color Choice : "))
            while color not in (1,2):
                print("ERROR ....!!\nYou selected wrong Choice....!!!")
                print("Please Select Choice Again....")
                print("\n\n1. Black\n2. White\n")
                color=int(input("Select Your Color Choice : "))
            betAmount=int(input("Enter Your Bet Amount : "))
            while betAmount<=0:
                print("ERROR ....!!\nYou entered wrong Bet Amount....!!!")
                print("Note :-  Bet Amount must be Greater than Zero (0)..!!!")
                betAmount=int(input("Enter Your Bet Amount : "))
            if betAmount<=data[userIndex]["amount"]:
                data[userIndex]["amount"]=data[userIndex]["amount"]-betAmount
                gameResult=random.randint(1,2)
                if gameResult==color:
                    print("Bravo....!!!\nYou WON the GAME.....!!!")
                    winAmount=betAmount*1.5
                    print("\nTotal Win Amount : ",winAmount)
                    data[userIndex]["amount"]=data[userIndex]["amount"]+winAmount
                else:
                    print("Sorry...!!!\nYoy Loose the GAME.....!!!")
            else:
                print("Alert.....!! Low Balance...!!!")
                print("Bet Amount must be smaller than Account Balance")
                print("Please ADD Money in your Account if you want to place this Bet ")
            playChoice=input("Do you want to play again ? (yes/no)...")
    else:
        print("Alert.....!! Low Balance...!!!")
        print("Please ADD Money in your Account ")
        
            

menu="yes"
while menu.lower()=="yes":
    print("ADDA 24X7")
    print("1. Create Acount")
    print("2. Add Money ")
    print("3. Withdraw Money ")
    print("4. Play Games")

    
    choice=int(input("Enter Your Choice : "))
    if choice==1:
        createAccount()
        print("\n Details in data are as follows \n",data) 
    elif choice==2:
        addMoney(data)
    elif choice==3:
        withdrawMoney(data)
    elif choice==4:
        gameMenu="yes"
        while gameMenu.lower()=="yes":
            print("Games Menu")
            print("1. Black & white")
            print("2. Lucky 10")
            gameChoice=int(input("Enter you choice : "))
            if gameChoice==1:
                BlackAndWhite(data)
            else:
                print("Wrong Choice")
            gameMenu=input("Do you want GAME menu again ? (yes/no) ....")
    else:
        print("Wrong Choice")
    menu=input("Do you want menu again ? (yes/no) ....")

    while isUserFound==False:
        for x in range(len(data)):
            if data[x]["id"]==id and data[x]["password"]==password:
                isUserFound=True
                userIndex=x
                print("-"*30,"Your Account Details","-"*30)
                print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
                print("-"*60)
        if isUserFound==False:
            print("Invalid Id or Password ......!!!!\n")
            print("Please Enter Correct Details Again....!!!\n")
            id=input("Enter User Id : ")
            password=input("Enter User Password : ")
            if isUserFound==True and data[userIndex]["amount"]>0:
                print("Welcome To Lucky 10")
                print("You have to Select 1 number out of 10 (ie. 1 t0 10)")
                print(" Winning Amount = Bet Amount * 9")
            select=int(input("Enter your lucky Number   :   "))
            betamount=int(input("Betting Amount  :  "))
            r=random.randrange(1,11)
            if select==r:
                print("Wow You won")
                amount=betamount*9
                data[x]["amount"]=data[x]["amount"]+amount   
import random
data=[]
total_users=0
def createAccount():
    user={}
    user["name"]=input("Enter user name=")
    global total_users
    total_users+=1
    user["id"]="ADDA"+str(total_users)
    user["password"]=input("Enter password=")
    user["amount"]=int(input("Enter opening account balance="))
    user["games_played"]=0
    data.append(user)
    print("Account Created Successfully ....!!!")
    print("-"*30,"Account Details","-"*30)
    print("\tUser Id:",user["id"],"\t\tUser Name:",user["name"],"\t\tBalance Amount:",user["amount"])
    print("-"*60)

def addMoney(data):
    id=input("Enter User Id : ")
    password=input("Enter User Password : ")
    isUserFound=False
    for x in range(len(data)):
        if data[x]["id"]==id and data[x]["password"]==password:
            isUserFound=True
            print("-"*30,"Your Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
            
            amount=int(input("Enter Amount To Add : "))
            data[x]["amount"]=data[x]["amount"]+amount
            
            print("Amount Added Successfully ....!!!")
            print("-"*30,"Updated Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
    if isUserFound==False:
        print("Invalid Id or Password ......!!!!\n")

def withdrawMoney(data):
    id=input("Enter User Id : ")
    password=input("Enter User Password : ")
    isUserFound=False
    for x in range(len(data)):
        if data[x]["id"]==id and data[x]["password"]==password:
            isUserFound=True
            print("-"*30,"Your Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
            
            amount=int(input("Enter Amount To Deduct/Withdraw : "))
            data[x]["amount"]=data[x]["amount"]-amount
            
            print("Amount Added Successfully ....!!!")
            print("-"*30,"Updated Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
    if isUserFound==False:
        print("Invalid Id or Password ......!!!!\n")

def BlackAndWhite(data):
    id=input("Enter User Id : ")
    password=input("Enter User Password : ")
    isUserFound=False
    userIndex=0
    while isUserFound==False:
        for x in range(len(data)):
            if data[x]["id"]==id and data[x]["password"]==password:
                isUserFound=True
                userIndex=x
                print("-"*30,"Your Account Details","-"*30)
                print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
                print("-"*60)
        if isUserFound==False:
            print("Invalid Id or Password ......!!!!\n")
            print("Please Enter Correct Details Again....!!!\n")
            id=input("Enter User Id : ")
            password=input("Enter User Password : ")
    if isUserFound==True and data[userIndex]["amount"]>0:
        print("Welcome To Black & White Game")
        print("Rules :\n1. You have To select your color(Black / White)\n2. Enter Bet Amount\n3. If your Selected color comes then You WON the game other You Loose")
        print("4. Winning Amount = Bet Amount * 1.5")
        gameRound=0
        playChoice="yes"
        while playChoice.lower()=="yes" and data[userIndex]["amount"]>0:
            gameRound+=1
            print("\t\t\tBlack & White")
            print("Round : ",gameRound,"\tWallet Balance : ",data[userIndex]["amount"],"\tTotal Games Played :",data[userIndex]["games_played"])
            data[userIndex]["games_played"]+=1
            print("\n\n1. Black\n2. White\n")
            color=int(input("Select Your Color Choice : "))
            while color not in (1,2):
                print("ERROR ....!!\nYou selected wrong Choice....!!!")
                print("Please Select Choice Again....")
                print("\n\n1. Black\n2. White\n")
                color=int(input("Select Your Color Choice : "))
            betAmount=int(input("Enter Your Bet Amount : "))
            while betAmount<=0:
                print("ERROR ....!!\nYou entered wrong Bet Amount....!!!")
                print("Note :-  Bet Amount must be Greater than Zero (0)..!!!")
                betAmount=int(input("Enter Your Bet Amount : "))
            if betAmount<=data[userIndex]["amount"]:
                data[userIndex]["amount"]=data[userIndex]["amount"]-betAmount
                gameResult=random.randint(1,2)
                if gameResult==color:
                    print("Bravo....!!!\nYou WON the GAME.....!!!")
                    winAmount=betAmount*1.5
                    print("\nTotal Win Amount : ",winAmount)
                    data[userIndex]["amount"]=data[userIndex]["amount"]+winAmount
                else:
                    print("Sorry...!!!\nYoy Loose the GAME.....!!!")
            else:
                print("Alert.....!! Low Balance...!!!")
                print("Bet Amount must be smaller than Account Balance")
                print("Please ADD Money in your Account if you want to place this Bet ")
            playChoice=input("Do you want to play again ? (yes/no)...")
    else:
        print("Alert.....!! Low Balance...!!!")
        print("Please ADD Money in your Account ")
        
            

menu="yes"
while menu.lower()=="yes":
    print("ADDA 24X7")
    print("1. Create Acount")
    print("2. Add Money ")
    print("3. Withdraw Money ")
    print("4. Play Games")

    
    choice=int(input("Enter Your Choice : "))
    if choice==1:
        createAccount()
        print("\n Details in data are as follows \n",data) 
    elif choice==2:
        addMoney(data)
    elif choice==3:
        withdrawMoney(data)
    elif choice==4:
        gameMenu="yes"
        while gameMenu.lower()=="yes":
            print("Games Menu")
            print("1. Black & white")
            print("2. Lucky 10")
            gameChoice=int(input("Enter you choice : "))
            if gameChoice==1:
                BlackAndWhite(data)
            else:
                print("Wrong Choice")
            gameMenu=input("Do you want GAME menu again ? (yes/no) ....")
    else:
        print("Wrong Choice")
    menu=input("Do you want menu again ? (yes/no) ....")

    while isUserFound==False:
        for x in range(len(data)):
            if data[x]["id"]==id and data[x]["password"]==password:
                isUserFound=True
                userIndex=x
                print("-"*30,"Your Account Details","-"*30)
                print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
                print("-"*60)
        if isUserFound==False:
            print("Invalid Id or Password ......!!!!\n")
            print("Please Enter Correct Details Again....!!!\n")
            id=input("Enter User Id : ")
            password=input("Enter User Password : ")
            if isUserFound==True and data[userIndex]["amount"]>0:
                print("Welcome To Lucky 10")
                print("You have to Select 1 number out of 10 (ie. 1 t0 10)")
                print(" Winning Amount = Bet Amount * 9")
            select=int(input("Enter your lucky Number   :   "))
            betamount=int(input("Betting Amount  :  "))
            r=random.randrange(1,11)
            if select==r:
                print("Wow You won")
                amount=betamount*9
                data[x]["amount"]=data[x]["amount"]+amount
             
        
    

    


            
    
import random
data=[]
total_users=0
def createAccount():
    user={}
    user["name"]=input("Enter user name=")
    global total_users
    total_users+=1
    user["id"]="ADDA"+str(total_users)
    user["password"]=input("Enter password=")
    user["amount"]=int(input("Enter opening account balance="))
    user["games_played"]=0
    data.append(user)
    print("Account Created Successfully ....!!!")
    print("-"*30,"Account Details","-"*30)
    print("\tUser Id:",user["id"],"\t\tUser Name:",user["name"],"\t\tBalance Amount:",user["amount"])
    print("-"*60)

def addMoney(data):
    id=input("Enter User Id : ")
    password=input("Enter User Password : ")
    isUserFound=False
    for x in range(len(data)):
        if data[x]["id"]==id and data[x]["password"]==password:
            isUserFound=True
            print("-"*30,"Your Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
            
            amount=int(input("Enter Amount To Add : "))
            data[x]["amount"]=data[x]["amount"]+amount
            
            print("Amount Added Successfully ....!!!")
            print("-"*30,"Updated Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
    if isUserFound==False:
        print("Invalid Id or Password ......!!!!\n")

def withdrawMoney(data):
    id=input("Enter User Id : ")
    password=input("Enter User Password : ")
    isUserFound=False
    for x in range(len(data)):
        if data[x]["id"]==id and data[x]["password"]==password:
            isUserFound=True
            print("-"*30,"Your Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
            
            amount=int(input("Enter Amount To Deduct/Withdraw : "))
            data[x]["amount"]=data[x]["amount"]-amount
            
            print("Amount Added Successfully ....!!!")
            print("-"*30,"Updated Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
    if isUserFound==False:
        print("Invalid Id or Password ......!!!!\n")

def BlackAndWhite(data):
    id=input("Enter User Id : ")
    password=input("Enter User Password : ")
    isUserFound=False
    userIndex=0
    while isUserFound==False:
        for x in range(len(data)):
            if data[x]["id"]==id and data[x]["password"]==password:
                isUserFound=True
                userIndex=x
                print("-"*30,"Your Account Details","-"*30)
                print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
                print("-"*60)
        if isUserFound==False:
            print("Invalid Id or Password ......!!!!\n")
            print("Please Enter Correct Details Again....!!!\n")
            id=input("Enter User Id : ")
            password=input("Enter User Password : ")
    if isUserFound==True and data[userIndex]["amount"]>0:
        print("Welcome To Black & White Game")
        print("Rules :\n1. You have To select your color(Black / White)\n2. Enter Bet Amount\n3. If your Selected color comes then You WON the game other You Loose")
        print("4. Winning Amount = Bet Amount * 1.5")
        gameRound=0
        playChoice="yes"
        while playChoice.lower()=="yes" and data[userIndex]["amount"]>0:
            gameRound+=1
            print("\t\t\tBlack & White")
            print("Round : ",gameRound,"\tWallet Balance : ",data[userIndex]["amount"],"\tTotal Games Played :",data[userIndex]["games_played"])
            data[userIndex]["games_played"]+=1
            print("\n\n1. Black\n2. White\n")
            color=int(input("Select Your Color Choice : "))
            while color not in (1,2):
                print("ERROR ....!!\nYou selected wrong Choice....!!!")
                print("Please Select Choice Again....")
                print("\n\n1. Black\n2. White\n")
                color=int(input("Select Your Color Choice : "))
            betAmount=int(input("Enter Your Bet Amount : "))
            while betAmount<=0:
                print("ERROR ....!!\nYou entered wrong Bet Amount....!!!")
                print("Note :-  Bet Amount must be Greater than Zero (0)..!!!")
                betAmount=int(input("Enter Your Bet Amount : "))
            if betAmount<=data[userIndex]["amount"]:
                data[userIndex]["amount"]=data[userIndex]["amount"]-betAmount
                gameResult=random.randint(1,2)
                if gameResult==color:
                    print("Bravo....!!!\nYou WON the GAME.....!!!")
                    winAmount=betAmount*1.5
                    print("\nTotal Win Amount : ",winAmount)
                    data[userIndex]["amount"]=data[userIndex]["amount"]+winAmount
                else:
                    print("Sorry...!!!\nYoy Loose the GAME.....!!!")
            else:
                print("Alert.....!! Low Balance...!!!")
                print("Bet Amount must be smaller than Account Balance")
                print("Please ADD Money in your Account if you want to place this Bet ")
            playChoice=input("Do you want to play again ? (yes/no)...")
    else:
        print("Alert.....!! Low Balance...!!!")
        print("Please ADD Money in your Account ")
        
            

menu="yes"
while menu.lower()=="yes":
    print("ADDA 24X7")
    print("1. Create Acount")
    print("2. Add Money ")
    print("3. Withdraw Money ")
    print("4. Play Games")

    
    choice=int(input("Enter Your Choice : "))
    if choice==1:
        createAccount()
        print("\n Details in data are as follows \n",data) 
    elif choice==2:
        addMoney(data)
    elif choice==3:
        withdrawMoney(data)
    elif choice==4:
        gameMenu="yes"
        while gameMenu.lower()=="yes":
            print("Games Menu")
            print("1. Black & white")
            print("2. Lucky 10")
            gameChoice=int(input("Enter you choice : "))
            if gameChoice==1:
                BlackAndWhite(data)
            else:
                print("Wrong Choice")
            gameMenu=input("Do you want GAME menu again ? (yes/no) ....")
    else:
        print("Wrong Choice")
    menu=input("Do you want menu again ? (yes/no) ....")

    while isUserFound==False:
        for x in range(len(data)):
            if data[x]["id"]==id and data[x]["password"]==password:
                isUserFound=True
                userIndex=x
                print("-"*30,"Your Account Details","-"*30)
                print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
                print("-"*60)
        if isUserFound==False:
            print("Invalid Id or Password ......!!!!\n")
            print("Please Enter Correct Details Again....!!!\n")
            id=input("Enter User Id : ")
            password=input("Enter User Password : ")
            if isUserFound==True and data[userIndex]["amount"]>0:
                print("Welcome To Lucky 10")
                print("You have to Select 1 number out of 10 (ie. 1 t0 10)")
                print(" Winning Amount = Bet Amount * 9")
            select=int(input("Enter your lucky Number   :   "))
            betamount=int(input("Betting Amount  :  "))
            r=random.randrange(1,11)
            if select==r:
                print("Wow You won")
                amount=betamount*9
                data[x]["amount"]=data[x]["amount"]+amount
import random
data=[]
total_users=0
def createAccount():
    user={}
    user["name"]=input("Enter user name=")
    global total_users
    total_users+=1
    user["id"]="ADDA"+str(total_users)
    user["password"]=input("Enter password=")
    user["amount"]=int(input("Enter opening account balance="))
    user["games_played"]=0
    data.append(user)
    print("Account Created Successfully ....!!!")
    print("-"*30,"Account Details","-"*30)
    print("\tUser Id:",user["id"],"\t\tUser Name:",user["name"],"\t\tBalance Amount:",user["amount"])
    print("-"*60)

def addMoney(data):
    id=input("Enter User Id : ")
    password=input("Enter User Password : ")
    isUserFound=False
    for x in range(len(data)):
        if data[x]["id"]==id and data[x]["password"]==password:
            isUserFound=True
            print("-"*30,"Your Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
            
            amount=int(input("Enter Amount To Add : "))
            data[x]["amount"]=data[x]["amount"]+amount
            
            print("Amount Added Successfully ....!!!")
            print("-"*30,"Updated Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
    if isUserFound==False:
        print("Invalid Id or Password ......!!!!\n")

def withdrawMoney(data):
    id=input("Enter User Id : ")
    password=input("Enter User Password : ")
    isUserFound=False
    for x in range(len(data)):
        if data[x]["id"]==id and data[x]["password"]==password:
            isUserFound=True
            print("-"*30,"Your Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
            
            amount=int(input("Enter Amount To Deduct/Withdraw : "))
            data[x]["amount"]=data[x]["amount"]-amount
            
            print("Amount Added Successfully ....!!!")
            print("-"*30,"Updated Account Details","-"*30)
            print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
            print("-"*60)
    if isUserFound==False:
        print("Invalid Id or Password ......!!!!\n")

def BlackAndWhite(data):
    id=input("Enter User Id : ")
    password=input("Enter User Password : ")
    isUserFound=False
    userIndex=0
    while isUserFound==False:
        for x in range(len(data)):
            if data[x]["id"]==id and data[x]["password"]==password:
                isUserFound=True
                userIndex=x
                print("-"*30,"Your Account Details","-"*30)
                print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
                print("-"*60)
        if isUserFound==False:
            print("Invalid Id or Password ......!!!!\n")
            print("Please Enter Correct Details Again....!!!\n")
            id=input("Enter User Id : ")
            password=input("Enter User Password : ")
    if isUserFound==True and data[userIndex]["amount"]>0:
        print("Welcome To Black & White Game")
        print("Rules :\n1. You have To select your color(Black / White)\n2. Enter Bet Amount\n3. If your Selected color comes then You WON the game other You Loose")
        print("4. Winning Amount = Bet Amount * 1.5")
        gameRound=0
        playChoice="yes"
        while playChoice.lower()=="yes" and data[userIndex]["amount"]>0:
            gameRound+=1
            print("\t\t\tBlack & White")
            print("Round : ",gameRound,"\tWallet Balance : ",data[userIndex]["amount"],"\tTotal Games Played :",data[userIndex]["games_played"])
            data[userIndex]["games_played"]+=1
            print("\n\n1. Black\n2. White\n")
            color=int(input("Select Your Color Choice : "))
            while color not in (1,2):
                print("ERROR ....!!\nYou selected wrong Choice....!!!")
                print("Please Select Choice Again....")
                print("\n\n1. Black\n2. White\n")
                color=int(input("Select Your Color Choice : "))
            betAmount=int(input("Enter Your Bet Amount : "))
            while betAmount<=0:
                print("ERROR ....!!\nYou entered wrong Bet Amount....!!!")
                print("Note :-  Bet Amount must be Greater than Zero (0)..!!!")
                betAmount=int(input("Enter Your Bet Amount : "))
            if betAmount<=data[userIndex]["amount"]:
                data[userIndex]["amount"]=data[userIndex]["amount"]-betAmount
                gameResult=random.randint(1,2)
                if gameResult==color:
                    print("Bravo....!!!\nYou WON the GAME.....!!!")
                    winAmount=betAmount*1.5
                    print("\nTotal Win Amount : ",winAmount)
                    data[userIndex]["amount"]=data[userIndex]["amount"]+winAmount
                else:
                    print("Sorry...!!!\nYoy Loose the GAME.....!!!")
            else:
                print("Alert.....!! Low Balance...!!!")
                print("Bet Amount must be smaller than Account Balance")
                print("Please ADD Money in your Account if you want to place this Bet ")
            playChoice=input("Do you want to play again ? (yes/no)...")
    else:
        print("Alert.....!! Low Balance...!!!")
        print("Please ADD Money in your Account ")
        
            

menu="yes"
while menu.lower()=="yes":
    print("ADDA 24X7")
    print("1. Create Acount")
    print("2. Add Money ")
    print("3. Withdraw Money ")
    print("4. Play Games")

    
    choice=int(input("Enter Your Choice : "))
    if choice==1:
        createAccount()
        print("\n Details in data are as follows \n",data) 
    elif choice==2:
        addMoney(data)
    elif choice==3:
        withdrawMoney(data)
    elif choice==4:
        gameMenu="yes"
        while gameMenu.lower()=="yes":
            print("Games Menu")
            print("1. Black & white")
            print("2. Lucky 10")
            gameChoice=int(input("Enter you choice : "))
            if gameChoice==1:
                BlackAndWhite(data)
            else:
                print("Wrong Choice")
            gameMenu=input("Do you want GAME menu again ? (yes/no) ....")
    else:
        print("Wrong Choice")
    menu=input("Do you want menu again ? (yes/no) ....")

    while isUserFound==False:
        for x in range(len(data)):
            if data[x]["id"]==id and data[x]["password"]==password:
                isUserFound=True
                userIndex=x
                print("-"*30,"Your Account Details","-"*30)
                print("\tUser Id:",data[x]["id"],"\t\tUser Name:",data[x]["name"],"\t\tBalance Amount:",data[x]["amount"])
                print("-"*60)
